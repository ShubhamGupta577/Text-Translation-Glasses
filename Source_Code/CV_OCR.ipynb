# %%
import cv2
# !pip install Pillow
# !sudo apt install tesseract-ocr
# !pip install pytesseract
from PIL import ImageEnhance, ImageFilter, Image
import pytesseract as ts
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (7.0.0)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# tesseract-ocr is already the newest version (4.00~git2288-10f4998a-2).
# 0 upgraded, 0 newly installed, 0 to remove and 13 not upgraded.
# Requirement already satisfied: pytesseract in /usr/local/lib/python3.6/dist-packages (0.3.7)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from pytesseract) (7.0.0)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#with open('/content/gdrive/My Drive/TTG', 'w') as f:
#  print(f.read())

# %%
#import matplotlib.pyplot as plt
#import numpy as np

#x = np.arange(20)
#y = [x_i + np.random.randn(1) for x_i in x]
#a, b = np.polyfit(x, y, 1)
#f = plt.figure()
#_ = plt.plot(x, y, 'o', np.arange(20), a*np.arange(20)+b, '-')

#f.savefig( "/content/gdrive/My Drive/TTG/test.png")

# %%
import os
print( os.getcwd() )
print( os.listdir() )
# Out:
# /content
# ['.config', 'gdrive', 'sample_data']

# %%
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode

def take_photo(filename='photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Wait for Capture to be clicked.
      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)
  data = eval_js('takePhoto({})'.format(quality))
  binary = b64decode(data.split(',')[1])
  with open(filename, 'wb') as f:
    f.write(binary)
  return filename

# %%
from IPython.display import Image
try:
  filename = take_photo()
  print('Saved to {}'.format(filename))
  
  # Show the image which was just taken.
  display(Image(filename))
except Exception as err:
  # Errors will be thrown if the user does not have a webcam or if they do not
  # grant the page permission to access it.
  print(str(err))
# Out:
# Saved to photo.jpg

# %%
 from google.colab.patches import cv2_imshow
 img = cv2.imread('photo.jpg',)
 gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
 ret, thresh = cv2.threshold(gray,1010, 200, cv2.THRESH_OTSU, cv2.THRESH_BINARY)
 text = ts.image_to_string(thresh)  
 cv2_imshow(thresh)   #printing realtime text
 print(text)
# Out:
# <PIL.Image.Image image mode=L size=640x480 at 0x7F31F009E198>
# iHola! Me llamo Sofia. Yo
# Chilena. Me gusta comer con
# mis amigos e ir aj cine.
# cantante y viajo mucho. Soy
# tubia y joven, No te
# ales en mi casa Porque
# viaio demasiado.

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
# This only needs to be done once in a notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# Create & upload a text file.
uploaded = drive.CreateFile({'title': 'Spanish.txt'})
uploaded.SetContentString(text)
uploaded.Upload()
print('Uploaded file with ID {}'.format(uploaded.get('id')))
ID = format(uploaded.get('id'))
# Out:
# Uploaded file with ID 1rkq5wb5pDtg-oh0t0JkR9vR1tI6fK3N3

# %%
uploaded
# Out:
# GoogleDriveFile({'title': 'Spanish.txt', 'mimeType': 'text/plain', 'kind': 'drive#file', 'id': '14H7xe0kuBOloBtCMTLfVTh6YIO065BJK', 'etag': '"MTYxMTg1MjM0OTAxMA"', 'selfLink': 'https://www.googleapis.com/drive/v2/files/14H7xe0kuBOloBtCMTLfVTh6YIO065BJK', 'webContentLink': 'https://drive.google.com/uc?id=14H7xe0kuBOloBtCMTLfVTh6YIO065BJK&export=download', 'alternateLink': 'https://drive.google.com/file/d/14H7xe0kuBOloBtCMTLfVTh6YIO065BJK/view?usp=drivesdk', 'embedLink': 'https://drive.google.com/file/d/14H7xe0kuBOloBtCMTLfVTh6YIO065BJK/preview?usp=drivesdk', 'iconLink': 'https://drive-thirdparty.googleusercontent.com/16/type/text/plain', 'labels': {'starred': False, 'hidden': False, 'trashed': False, 'restricted': False, 'viewed': True}, 'copyRequiresWriterPermission': False, 'createdDate': '2021-01-28T16:45:49.010Z', 'modifiedDate': '2021-01-28T16:45:49.010Z', 'modifiedByMeDate': '2021-01-28T16:45:49.010Z', 'lastViewedByMeDate': '2021-01-28T16:45:49.010Z', 'markedViewedByMeDate': '1970-01-01T00:00:00.000Z', 'version': '1', 'parents': [{'kind': 'drive#parentReference', 'id': '0AI-9oSBleVpMUk9PVA', 'selfLink': 'https://www.googleapis.com/drive/v2/files/14H7xe0kuBOloBtCMTLfVTh6YIO065BJK/parents/0AI-9oSBleVpMUk9PVA', 'parentLink': 'https://www.googleapis.com/drive/v2/files/0AI-9oSBleVpMUk9PVA', 'isRoot': True}], 'downloadUrl': 'https://www.googleapis.com/drive/v2/files/14H7xe0kuBOloBtCMTLfVTh6YIO065BJK?alt=media&source=downloadUrl', 'userPermission': {'kind': 'drive#permission', 'etag': '"w8VrKgcY-LNdAGcAEPdAH23mycM"', 'id': 'me', 'selfLink': 'https://www.googleapis.com/drive/v2/files/14H7xe0kuBOloBtCMTLfVTh6YIO065BJK/permissions/me', 'role': 'owner', 'type': 'user'}, 'originalFilename': 'Spanish.txt', 'fileExtension': 'txt', 'md5Checksum': '262c9a3db8dc032c71cea7f4c5441b8a', 'fileSize': '169', 'quotaBytesUsed': '169', 'ownerNames': ['Experiment Mail'], 'owners': [{'kind': 'drive#user', 'displayName': 'Experiment Mail', 'isAuthenticatedUser': True, 'permissionId': '00894835917889283891', 'emailAddress': 'experimailment@gmail.com'}], 'lastModifyingUserName': 'Experiment Mail', 'lastModifyingUser': {'kind': 'drive#user', 'displayName': 'Experiment Mail', 'isAuthenticatedUser': True, 'permissionId': '00894835917889283891', 'emailAddress': 'experimailment@gmail.com'}, 'capabilities': {'canCopy': True, 'canEdit': True}, 'editable': True, 'copyable': True, 'writersCanShare': True, 'shared': False, 'explicitlyTrashed': False, 'appDataContents': False, 'headRevisionId': '0B4-9oSBleVpMZkVHS0xEYlk0bEovZ01uNkdUUjR3T0FaaWZJPQ', 'spaces': ['drive']})

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
# This only needs to be done once per notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# Download a file based on its file ID.
#
# A file ID looks like: laggVyWshwcyP6kEI-y_W3P8D26sz
file_id = ID
downloaded = drive.CreateFile({'id': file_id})
print('Downloaded content "{}"'.format(downloaded.GetContentString()))
# Out:
# Downloaded content "iHola! Me llamo Sofia. Yo
# Chilena. Me gusta comer con
# mis amigos e ir aj cine.
# cantante y viajo mucho. Soy
# tubia y joven, No te
# ales en mi casa Porque
# viaio demasiado.
# "
